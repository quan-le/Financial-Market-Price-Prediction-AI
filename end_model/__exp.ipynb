# %%
from CONFIG.config import *

# %%
import pickle
import os

# %%
os.listdir(DATASET_DIR.joinpath("features"))
# Out:
# ['BTC_scaler.pkl', 'BTC_features.parquet']

# %%
with DATASET_DIR.joinpath("features").joinpath("BTC_scaler.pkl").open("rb") as f:
    data = pickle.load(f)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[18], line 2
#       1 with DATASET_DIR.joinpath("features").joinpath("BTC_scaler.pkl").open("rb") as f:
# ----> 2     data = pickle.load(f)
#
# UnpicklingError: STACK_GLOBAL requires str
